# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("train.csv")
test_train_df = pd.read_csv("test.csv")
train_df['datetime'] = pd.to_datetime(train_df['datetime'])

jun21_df = train_df[(train_df["datetime"].dt.year == 2012) & (train_df["datetime"].dt.month == 9) & (train_df["datetime"].dt.day <= 13) & (train_df["datetime"].dt.day >= 7)]
jun21_df
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 9207 2012-09-07 00:00:00       3        0           1        1  26.24  28.790
# 9208 2012-09-07 01:00:00       3        0           1        1  25.42  28.030
# 9209 2012-09-07 02:00:00       3        0           1        1  25.42  28.790
# 9210 2012-09-07 03:00:00       3        0           1        1  25.42  28.790
# 9211 2012-09-07 04:00:00       3        0           1        1  25.42  28.030
# ...                  ...     ...      ...         ...      ...    ...     ...
# 9370 2012-09-13 19:00:00       3        0           1        1  26.24  30.305
# 9371 2012-09-13 20:00:00       3        0           1        1  25.42  30.305
# 9372 2012-09-13 21:00:00       3        0           1        1  25.42  30.305
# 9373 2012-09-13 22:00:00       3        0           1        1  24.60  29.545
# 9374 2012-09-13 23:00:00       3        0           1        1  23.78  27.275
#
# ...

# %%
# Plotting the total 'count' of bike rentals over time
plt.figure(figsize=(14,8))  # Set figure size
plt.plot(jun21_df["datetime"], jun21_df['count'], label='Nombre de locations par heure')
plt.plot(jun21_df["datetime"], 200*(jun21_df['weather']-1), label='Météo')

# Add title and labels
plt.title('Impact de la météo')
plt.xlabel('Date')
plt.ylabel('Nombre de locations')
plt.grid()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display legend
plt.legend()

# Display the plot
plt.tight_layout()  # Adjust layout to prevent label overlap
plt.show()
